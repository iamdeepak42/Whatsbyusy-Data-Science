# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('test_restaurant.csv')

# %%
df.head()
# Out:
#          date  num_visitors
# 0  2000-01-01     49.128490
# 1  2000-01-02     50.288060
# 2  2000-01-03     53.549213
# 3  2000-01-04     45.453240
# 4  2000-01-05     49.469402

# %%
#Check for missing values
df.isnull().sum()
# Out:
# date            0
# num_visitors    0
# dtype: int64

# %%
#Find number of rows and columns in the dataframe
df.shape
# Out:
# (3651, 2)

# %%
#Check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# Check if same date has been repeated twice
df.date.duplicated().sum()
# Out:
# 0

# %%
#Change date column to datetime and setting the date as index
df.date = pd.to_datetime(df.date)
df.set_index('date',inplace = True)

# %%
# Summary statistics for the data frame

df.describe()
# Out:
#        num_visitors
# count   3651.000000
# mean      24.782759
# std       11.188746
# min       -7.867497
# 25%       17.042217
# 50%       22.950304
# 75%       29.260646
# max       69.849130

# %% [markdown]
# As we can see from the summary above, the minimum number for the visitor is -7.96 which is not usual. So we are going to check those cases.

# %%
df[df['num_visitors'] < 0]
# Out:
#             num_visitors
# date
# 2000-02-06     -1.293132
# 2001-02-05     -7.867497

# %%
# Here it is best to remove these entries as number of visitors can never be negative or this may be a typo.
df = df[df['num_visitors'] >= 0]

# %%
df.describe()
# Out:
#        num_visitors
# count   3649.000000
# mean      24.798853
# std       11.170399
# min        0.181759
# 25%       17.052917
# 50%       22.961277
# 75%       29.262848
# max       69.849130

# %%
#Plotting the time series
df.plot(grid=True)
plt.show()

# %% [markdown]
# From the above graph, we are able to capture the trend of num_visitors going upward yearly.

# %% [markdown]
# On closer observation it is seen that number of visitor seem to peak at the end/starting of a year.

# %%
df.rolling(365).mean().plot(label='365 days Rolling Mean')
plt.title('365 days Rolling Mean')
plt.show()

# %% [markdown]
# As we see the data tends to be following a seasonal pattern having an upward trend
#
# Now we will be seeing the seasonality trend and residuals by using ETS decomposition:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(df, freq=365)  
figure = plt.figure()  
figure = decomposition.plot()  
figure.set_size_inches(15, 8)

# %% [markdown]
# ## ACDF Test

# %% [markdown]
# The data is indeed seasonal and follows an upward trend.
# Also, the average value or the mean of the residuals seem to be nearly about  zero (in all yers except 2001) which holds our assumption.
#
# Now we will check whether the data is stationary or not. For this, we will perform a test called the Dickey-Fuller test. In the field of statistics, the Dickey-Fuller test (ADF) is used to test the null hypothesis (which is the Data is not stationary)

# %%
adfuller(df['num_visitors'])
# Out:
# (-4.295387470823104,
#  0.0004524535390281959,
#  30,
#  3618,
#  {'1%': -3.432158719084614,
#   '5%': -2.8623391910775715,
#   '10%': -2.567195421889386},
#  21699.67374424213)

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(df['num_visitors'],autolag = 'AIC')
dftest
# Out:
# (-4.295387470823104,
#  0.0004524535390281959,
#  30,
#  3618,
#  {'1%': -3.432158719084614,
#   '5%': -2.8623391910775715,
#   '10%': -2.567195421889386},
#  21699.67374424213)

# %%
from statsmodels.tsa.stattools import adfuller
test_result = adfuller(df['num_visitors'])
print ('ADF Test:')
labels = ['ADF Statistic','p-value','No. of Lags Used','Number of Observations Used']

for value,label in zip(test_result,labels):
    print (label+': '+str(value))
if test_result[1] <= 0.05:
    print ("Reject null hypothesis and data is stationary")
else:
    print ("Fail to reject H0 thereby data is non-stationary ")
# Out:
# ADF Test:
# ADF Statistic: -4.295387470823104
# p-value: 0.0004524535390281959
# No. of Lags Used: 30
# Number of Observations Used: 3618
# Reject null hypothesis and data is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig_first = plot_acf(df["num_visitors"].shift(30).dropna())
